# %% [markdown]
# # Hierarchical Clustering
# - Start each node in its own cluster.
# - Find two closet clusters and merge them togther.
# - Repeat the alogrithm untill all the points are in the same cluster.

# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import linkage, dendrogram

# Given data
x = np.array([[1,1],[1.5,1],[3,3],[4,4],[3,3.5],[3.5,4]])

# Plot the given data
plt.scatter(x[:,0], x[:,1], s= 50)
plt.title("Data set")
plt.show()

# Hierarchy clustering
linkage_matrix = linkage(x, 'single')
dendrogram = dendrogram(linkage_matrix, truncate_mode='none')

plt.title("Hierarchical Clustering")
plt.show()
